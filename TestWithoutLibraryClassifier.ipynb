# %%
import numpy as np
import pandas as pd
import nltk
import string

from bs4 import BeautifulSoup
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.externals import joblib

# %%
df = pd. read_csv('test.csv',header=None, delimiter=',', skiprows=1, names=['text','label'])
df.shape
# Out:
# (5000, 2)

# %%
ds = df[["text"]]
df.head()
# Out:
#                                                 text  label
# 0  I always wrote this series off as being a comp...      0
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0
# 2  This movie was so poorly written and directed ...      0
# 3  The most interesting thing about Miryang (Secr...      1
# 4  when i first read about "berlin am meer" i did...      0

# %%
ds["lower"] = ds["text"].str.lower()
ds.head()
# Out:
#                                                 text  \
# 0  I always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...
# 2  This movie was so poorly written and directed ...
# 3  The most interesting thing about Miryang (Secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                                lower
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...

# %%
def remove_html_tags(text):
    return BeautifulSoup(text, "lxml").text

ds["no_tags"] = ds["lower"].apply(lambda text: remove_html_tags(text))
ds.head()
# Out:
#                                                 text  \
# 0  I always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...
# 2  This movie was so poorly written and directed ...
# 3  The most interesting thing about Miryang (Secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                                lower  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                              no_tags
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...

# %%
PUNCT_TO_REMOVE = string.punctuation

def remove_punctuation(text):
    return text.translate(str.maketrans(' ', ' ', PUNCT_TO_REMOVE))

ds["no_punct"] = ds["no_tags"].apply(lambda text: remove_punctuation(text))
ds.head()
# Out:
#                                                 text  \
# 0  I always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...
# 2  This movie was so poorly written and directed ...
# 3  The most interesting thing about Miryang (Secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                                lower  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                              no_tags  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                             no_punct
# 0  i always wrote this series off as being a comp...
# 1  1st watched 1272002  3 out of 10dirsteve purce...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang secre...
# 4  when i first read about berlin am meer i didnt...

# %%
def remove_numbers(text):
    
    return " ".join([line for line in str(text).split() if not line.isdigit()])

ds["no_num"] = ds["no_punct"].apply(lambda text: remove_numbers(text))
ds.head()
# Out:
#                                                 text  \
# 0  I always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...
# 2  This movie was so poorly written and directed ...
# 3  The most interesting thing about Miryang (Secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                                lower  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                              no_tags  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                             no_punct  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 1272002  3 out of 10dirsteve purce...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang secre...
# 4  when i first read about berlin am meer i didnt...
#
#                                               no_num
# 0  i always wrote this series off as being a comp...
# 1  1st watched out of 10dirsteve purcell typical ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang secre...
# 4  when i first read about berlin am meer i didnt...

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

ds["no_stopwords"] = ds["no_num"].apply(lambda text: remove_stopwords(text))
ds.head()
# Out:
#                                                 text  \
# 0  I always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...
# 2  This movie was so poorly written and directed ...
# 3  The most interesting thing about Miryang (Secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                                lower  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                              no_tags  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                             no_punct  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 1272002  3 out of 10dirsteve purce...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang secre...
# 4  when i first read about berlin am meer i didnt...
#
#                                               no_num  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched out of 10dirsteve purcell typical ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang secre...
# 4  when i first read about berlin am meer i didnt...
#
#                                         no_stopwords
# 0  always wrote series complete stinkfest jim bel...
# 1  1st watched 10dirsteve purcell typical mary ka...
# 2  movie poorly written directed fell asleep minu...
# 3  interesting thing miryang secret sunshine acto...
# 4  first read berlin meer didnt expect much thoug...

# %%
lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}

def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

ds["lemmatized"] = ds["no_stopwords"].apply(lambda text: lemmatize_words(text))
ds.head()
# Out:
#                                                 text  \
# 0  I always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...
# 2  This movie was so poorly written and directed ...
# 3  The most interesting thing about Miryang (Secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                                lower  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                              no_tags  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 12/7/2002 - 3 out of 10(dir-steve ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang (secr...
# 4  when i first read about "berlin am meer" i did...
#
#                                             no_punct  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched 1272002  3 out of 10dirsteve purce...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang secre...
# 4  when i first read about berlin am meer i didnt...
#
#                                               no_num  \
# 0  i always wrote this series off as being a comp...
# 1  1st watched out of 10dirsteve purcell typical ...
# 2  this movie was so poorly written and directed ...
# 3  the most interesting thing about miryang secre...
# 4  when i first read about berlin am meer i didnt...
#
#                                         no_stopwords  \
# 0  always wrote series complete stinkfest jim bel...
# 1  1st watched 10dirsteve purcell typical mary ka...
# 2  movie poorly written directed fell asleep minu...
# 3  interesting thing miryang secret sunshine acto...
# 4  first read berlin meer didnt expect much thoug...
#
#                                           lemmatized
# 0  always write series complete stinkfest jim bel...
# 1  1st watch 10dirsteve purcell typical mary kate...
# 2  movie poorly write direct fell asleep minute m...
# 3  interesting thing miryang secret sunshine acto...
# 4  first read berlin meer didnt expect much think...

# %%
vectorizer = TfidfVectorizer(min_df=0.0015, ngram_range=(1,3))
fitted_vectorizer = vectorizer.fit(ds["lemmatized"])

# %%
len(fitted_vectorizer.vocabulary_)
# Out:
# 10734

# %%
fitted_vectorizer.vocabulary_
# Out:
# {'always': 358,
#  'write': 10630,
#  'series': 8417,
#  'complete': 1687,
#  'jim': 4879,
#  'belushi': 851,
#  'involve': 4769,
#  'heavily': 4275,
#  'one': 6675,
#  'day': 2033,
#  'tragic': 9706,
#  'occur': 6617,
#  'white': 10395,
#  'game': 3700,
#  'end': 2661,
#  'realize': 7630,
#  'remote': 7814,
#  'way': 10263,
#  'side': 8576,
#  'room': 8009,
#  'somehow': 8753,
#  'could': 1827,
#  'get': 3744,
#  'across': 94,
#  'even': 2800,
#  'tv': 9816,
#  'turn': 9807,
#  'channel': 1352,
#  'walk': 10129,
#  'country': 1875,
#  'watch': 10216,
#  'another': 434,
#  'state': 8943,
#  'nut': 6593,
#  'say': 8131,
#  'hang': 4184,
#  'tight': 9564,
#  'couch': 1826,
#  'take': 9263,
#  'whatever': 10378,
#  'fate': 3102,
#  'store': 9010,
#  'episode': 2757,
#  'show': 8528,
#  'remember': 7800,
#  'little': 5361,
#  'except': 2928,
#  'make': 5578,
#  'broad': 1103,
#  'general': 3722,
#  'sweep': 9234,
#  'judgment': 4921,
#  'base': 763,
#  'zero': 10729,
#  'objective': 6599,
#  'evidence': 2900,
#  'nothing': 6554,
#  'whatsoever': 10382,
#  'back': 663,
#  'opinion': 6809,
#  'completely': 1691,
#  'right': 7939,
#  'total': 9680,
#  'comedic': 1633,
#  'delivery': 2121,
#  'woman': 10477,
#  'physically': 7118,
#  'attractive': 610,
#  'real': 7612,
#  'feel': 3128,
#  'viewer': 10072,
#  'absolutely': 53,
#  'reason': 7692,
#  'stop': 9008,
#  'run': 8041,
#  'local': 5388,
#  'station': 8946,
#  'send': 8389,
#  'every': 2862,
#  'copy': 1806,
#  'howl': 4455,
#  'hell': 4285,
#  'wonderful': 10486,
#  'comic': 1645,
#  'larry': 5106,
#  'joe': 4890,
#  'campbell': 1202,
#  'great': 4057,
#  'character': 1357,
#  'actor': 141,
#  'guy': 4138,
#  'play': 7167,
#  'andy': 408,
#  'gold': 3943,
#  'good': 3949,
#  'really': 7633,
#  'well': 10310,
#  'aside': 558,
#  'funny': 3672,
#  'job': 4884,
#  'look': 5413,
#  'thats': 9383,
#  'like': 5269,
#  'try': 9775,
#  'butt': 1166,
#  'pull': 7482,
#  'style': 9107,
#  'someone': 8755,
#  'invent': 4760,
#  'prize': 7399,
#  'win': 10438,
#  'year': 10659,
#  'without': 10461,
#  'would': 10548,
#  'consist': 1754,
#  'slightly': 8685,
#  'smack': 8699,
#  'head': 4251,
#  'fry': 3647,
#  'pan': 6916,
#  'beat': 794,
#  'chest': 1435,
#  'floor': 3526,
#  'cage': 1180,
#  'star': 8920,
#  'bacon': 678,
#  'improve': 4600,
#  'flavor': 3511,
#  'everything': 2893,
#  'he': 4246,
#  'one day': 6693,
#  'could get': 1839,
#  'watch tv': 10247,
#  'tv station': 9821,
#  'character actor': 1359,
#  'guy play': 4147,
#  'good really': 3992,
#  'really well': 7686,
#  'job make': 4887,
#  'look good': 5428,
#  'like try': 5325,
#  'try make': 9790,
#  'every year': 2880,
#  'show would': 8558,
#  '1st': 12,
#  'typical': 9866,
#  'mary': 5748,
#  'kate': 4950,
#  'fare': 3084,
#  'kiss': 5016,
#  'girl': 3830,
#  'pretty': 7362,
#  'tire': 9624,
#  'stuff': 9096,
#  'interest': 4724,
#  'happens': 4194,
#  'ever': 2844,
#  'decide': 2071,
#  'split': 8875,
#  'go': 3885,
#  'adventure': 219,
#  'rome': 8002,
#  'fashion': 3093,
#  'designer': 2162,
#  'put': 7503,
#  'learn': 5173,
#  'work': 10505,
#  'hard': 4202,
#  'guess': 4123,
#  'besides': 865,
#  'boys': 1045,
#  'much': 6281,
#  'else': 2630,
#  'scenario': 8176,
#  'movie': 6027,
#  'finally': 3424,
#  'reveal': 7897,
#  'fire': 3457,
#  'people': 7006,
#  'dont': 2392,
#  'understand': 9903,
#  'corporate': 1811,
#  'world': 10518,
#  'interpretation': 4744,
#  'maybe': 5789,
#  'next': 6483,
#  'kid': 4982,
#  'didnt': 2207,
#  'seem': 8362,
#  'care': 1254,
#  'boring': 1021,
#  'let': 5215,
#  'see': 8280,
#  'probably': 7401,
#  'couple': 1879,
#  'till': 9566,
#  'legal': 5199,
#  'adult': 215,
#  'look like': 5430,
#  'like girl': 5290,
#  'girl get': 3831,
#  'get pretty': 3793,
#  'go way': 3930,
#  'work hard': 10511,
#  'much else': 6284,
#  'way movie': 10277,
#  'movie finally': 6097,
#  'make people': 5633,
#  'people dont': 7014,
#  'dont understand': 2426,
#  'real world': 7622,
#  'one even': 6700,
#  'didnt seem': 2223,
#  'let see': 5227,
#  'couple year': 1882,
#  'well see': 10342,
#  'poorly': 7267,
#  'direct': 2258,
#  'fell': 3142,
#  'asleep': 562,
#  'minute': 5913,
#  'joke': 4904,
#  'corny': 1810,
#  'though': 9521,
#  'plot': 7201,
#  'interesting': 4731,
#  'angle': 414,
#  'far': 3069,
#  'fetch': 3161,
#  'point': 7236,
#  'ridiculous': 7935,
#  'old': 6649,
#  'overlook': 6880,
#  'disappointed': 2289,
#  'young': 10697,
#  'film': 3188,
#  'capture': 1245,
#  'attention': 604,
#  'amaze': 371,
#  'stunt': 9103,
#  'might': 5874,
#  'add': 191,
#  'do': 2346,
#  'wish': 10451,
#  'warrior': 10189,
#  'cast': 1284,
#  'wasnt': 10193,
#  'music': 6327,
#  'disappoint': 2288,
#  'build': 1134,
#  'tension': 9356,
#  'fit': 3498,
#  'scale': 8166,
#  'excellent': 2921,
#  'horrible': 4410,
#  'acting': 129,
#  'brenda': 1075,
#  'song': 8784,
#  'talented': 9290,
#  'comedy': 1634,
#  'kind': 5002,
#  'serious': 8422,
#  'scene': 8177,
#  'act': 95,
#  'laughable': 5139,
#  'fighting': 3183,
#  'pose': 7289,
#  'start': 8930,
#  'laugh': 5133,
#  'loud': 5474,
#  'think': 9458,
#  'bad': 679,
#  'thing': 9429,
#  'definitely': 2099,
#  'example': 2916,
#  'part': 6935,
#  'enemy': 2692,
#  'person': 7077,
#  'evil': 2903,
#  'villain': 10078,
#  'voice': 10106,
#  'dark': 2014,
#  'incredibly': 4627,
#  'stupid': 9104,
#  'teacher': 9319,
#  'school': 8213,
#  'possess': 7294,
#  'monk': 5974,
#  'disappointing': 2290,
#  'okay': 6647,
#  'youre': 10713,
#  'poorly write': 7271,
#  'write direct': 10635,
#  'fell asleep': 3143,
#  'minute movie': 5917,
#  'even though': 2830,
#  'far fetch': 3075,
#  'write movie': 10637,
#  'poorly do': 7269,
#  'movie wasnt': 6247,
#  'wasnt good': 10199,
#  'good music': 3981,
#  'kind movie': 5005,
#  'laugh loud': 5137,
#  'think bad': 9463,
#  'bad thing': 724,
#  'thing movie': 9446,
#  'movie definitely': 6065,
#  'secret': 8271,
#  'sunshine': 9167,
#  'lee': 5194,
#  'main': 5563,
#  'son': 8783,
#  'whose': 10416,
#  'husband': 4488,
#  'die': 2229,
#  'accident': 74,
#  'leave': 5181,
#  'live': 5375,
#  'home': 4374,
#  'town': 9694,
#  'face': 3013,
#  'elegant': 2616,
#  'age': 242,
#  'sad': 8064,
#  'desperate': 2166,
#  'terribly': 9365,
#  'isolate': 4803,
#  'also': 318,
#  'kim': 5000,
#  'man': 5674,
#  'meet': 5815,
#  'car': 1248,
#  'break': 1066,
#  'come': 1604,
#  'garage': 3705,
#  'follow': 3543,
#  'around': 526,
#  'time': 9568,
#  'thereafter': 9412,
#  'despite': 2172,
#  'apparent': 489,
#  'lack': 5086,
#  'big': 906,
#  'renowned': 7819,
#  'park': 6932,
#  'sympathy': 9249,
#  'mr': 6276,
#  'vengeance': 10036,
#  'memory': 5830,
#  'murder': 6317,
#  'host': 4431,
#  'yet': 10679,
#  'almost': 300,
#  'forgotten': 3571,
#  'course': 1884,
#  'curiously': 1972,
#  'appeal': 492,
#  'essential': 2779,
#  'keep': 4957,
#  'float': 3524,
#  'piano': 7120,
#  'new': 6469,
#  'neutral': 6432,
#  'place': 7150,
#  'anywhere': 482,
#  'anyone': 460,
#  'boy': 1042,
#  'plainly': 7157,
#  'damage': 1996,
#  'father': 3103,
#  'use': 9990,
#  'miss': 5931,
#  'lie': 5244,
#  'awake': 640,
#  'pretend': 7359,
#  'parent': 6930,
#  'student': 9093,
#  'sense': 8395,
#  'speak': 8834,
#  'dialect': 2198,
#  'everyone': 2884,
#  'know': 5024,
#  'origin': 6830,
#  'immediately': 4576,
#  'noticed': 6570,
#  'life': 5245,
#  'away': 646,
#  'city': 1495,
#  'danger': 2007,
#  'terrible': 9360,
#  'doesnt': 2360,
#  'necessarily': 6397,
#  'deal': 2047,
#  'best': 866,
#  'possible': 7297,
#  'happen': 4187,
#  'must': 6337,
#  'consequence': 1745,
#  'cant': 1217,
#  'piece': 7126,
#  'catch': 1301,
#  'eventually': 2841,
#  'become': 807,
#  'despair': 2165,
#  'christian': 1464,
#  'meeting': 5816,
#  'acquaintance': 92,
#  'press': 7355,
#  'attend': 602,
#  'find': 3430,
#  'peace': 6990,
#  'release': 7781,
#  'forgive': 3569,
#  'prison': 7395,
#  'tell': 9340,
#  'experience': 2969,
#  'full': 3654,
#  'irony': 4780,
#  'destroy': 2177,
#  'becomes': 811,
#  'long': 5401,
#  'religion': 7790,
#  'give': 3835,
#  'extremely': 3002,
#  'role': 7988,
#  'may': 5772,
#  'director': 2264,
#  'express': 2990,
#  'enormous': 2716,
#  'admiration': 205,
#  'convince': 1795,
#  'accord': 81,
#  'scott': 8231,
#  'la': 5080,
#  'first': 3460,
#  'three': 9536,
#  'green': 4094,
#  'fish': 3493,
#  'candy': 1211,
#  'mark': 5730,
#  'lead': 5158,
#  'figure': 3184,
#  'recent': 7709,
#  'cinematic': 1486,
#  'successful': 9136,
#  'korean': 5069,
#  'ive': 4819,
#  'gift': 3822,
#  'indeed': 4628,
#  'begin': 817,
#  'alice': 282,
#  'anymore': 459,
#  'abruptly': 49,
#  'warn': 10182,
#  'something': 8763,
#  'thriller': 9543,
#  'nearly': 6394,
#  'study': 9095,
#  'human': 4467,
#  'suffer': 9143,
#  'progression': 7432,
#  'random': 7569,
#  'lose': 5451,
#  'momentum': 5968,
#  'toward': 9689,
#  'simply': 8608,
#  'action': 130,
#  'foolish': 3550,
#  'chance': 1344,
#  'choice': 1453,
#  'along': 310,
#  'destine': 2175,
#  'madness': 5550,
#  'betty': 897,
#  'blue': 981,
#  'explain': 2976,
#  'peculiar': 6996,
#  'mistaken': 5941,
#  'isnt': 4789,
#  'properly': 7450,
#  'develop': 2187,
#  'certainly': 1332,
#  'disturb': 2336,
#  'emotional': 2648,
#  'official': 6632,
#  'selection': 8381,
#  'york': 10685,
#  'festival': 3160,
#  'present': 7349,
#  'lincoln': 5338,
#  'center': 1324,
#  'event': 2837,
#  'filmmaker': 3413,
#  'past': 6962,
#  'interesting thing': 4735,
#  'main character': 5565,
#  'film also': 3196,
#  'also star': 345,
#  'around time': 528,
#  'big star': 917,
#  'character almost': 1360,
#  'anyone else': 462,
#  'little boy': 5363,
#  'go school': 3921,
#  'place film': 7151,
#  'film even': 3243,
#  'everyone know': 2887,
#  'know everything': 5029,
#  'life really': 5257,
#  'big city': 908,
#  'get bad': 3749,
#  'may good': 5777,
#  'good director': 3958,
#  'first three': 3486,
#  'three film': 9537,
#  'ive see': 4827,
#  'turn something': 9812,
#  'toward end': 9690,
#  'make bad': 5584,
#  'interesting film': 4733,
#  'film certainly': 3221,
#  'one one': 6748,
#  'one leave': 6726,
#  'leave one': 5187,
#  'new york': 6476,
#  'film festival': 3260,
#  'do right': 2350,
#  'read': 7602,
#  'berlin': 862,
#  'expect': 2958,
#  'location': 5391,
#  'least': 5175,
#  'trivial': 9757,
#  'hip': 4340,
#  'talk': 9293,
#  'fail': 3025,
#  'ridiculously': 7936,
#  'call': 1185,
#  'sell': 8386,
#  'definite': 2098,
#  'movieand': 6269,
#  'apart': 484,
#  'credibility': 1918,
#  'mediocre': 5812,
#  'rather': 7590,
#  'bore': 1017,
#  'interestingly': 4737,
#  'prove': 7461,
#  'actually': 170,
#  'quite': 7533,
#  'poor': 7263,
#  'bother': 1028,
#  'unless': 9950,
#  'small': 8700,
#  'western': 10371,
#  'germany': 3742,
#  'want': 10146,
#  'move': 6021,
#  'finish': 3455,
#  'enjoyable': 2709,
#  'totally': 9682,
#  'cool': 1801,
#  'didnt expect': 2210,
#  'expect much': 2963,
#  'think right': 9496,
#  'least make': 5178,
#  'everyone seem': 2891,
#  'expect movie': 2962,
#  'movie thats': 6226,
#  'really bad': 7635,
#  'bad movie': 704,
#  'movie actually': 6031,
#  'actually quite': 180,
#  'small town': 8705,
#  'actually find': 171,
#  'really bad movie': 7636,
#  'saw': 8125,
#  'judge': 4920,
#  'screen': 8237,
#  'truly': 9769,
#  'picture': 7124,
#  'award': 642,
#  'explore': 2985,
#  'journey': 4914,
#  'hope': 4397,
#  'respect': 7864,
#  'positive': 7291,
#  'value': 10016,
#  'filmthis': 3417,
#  'story': 9012,
#  'golf': 3947,
#  'early': 2542,
#  '20th': 14,
#  'century': 1329,
#  'upper': 9980,
#  'class': 1508,
#  'rich': 7924,
#  'gentleman': 3733,
#  'participate': 6947,
#  'club': 1564,
#  'backdrop': 673,
#  'unfolds': 9924,
#  'harry': 4229,
#  'inspirational': 4690,
#  'odds': 6622,
#  'francis': 3600,
#  'hole': 4361,
#  'compete': 1681,
#  'britain': 1099,
#  'open': 6798,
#  'child': 1443,
#  'hilarious': 4330,
#  'steal': 8952,
#  'appear': 493,
#  'handicap': 4181,
#  'display': 2321,
#  'courage': 1883,
#  'spirit': 8869,
#  'lot': 5458,
#  'wooden': 10499,
#  'short': 8513,
#  'swing': 9238,
#  'mouth': 6020,
#  'condition': 1721,
#  'cancel': 1207,
#  'stun': 9100,
#  'cinematography': 1488,
#  'art': 540,
#  'direction': 2262,
#  'edit': 2573,
#  'sport': 8885,
#  'vein': 10035,
#  'miracle': 5920,
#  'web': 10299,
#  'site': 8644,
#  'winner': 10443,
#  'saw film': 8126,
#  'film truly': 3385,
#  '20th century': 15,
#  'upper class': 9981,
#  'people could': 7011,
#  'work class': 10507,
#  'every scene': 2873,
#  'art direction': 541,
#  'movie star': 6213,
#  'go back': 3892,
#  'last': 5107,
#  'night': 6508,
#  'high': 4316,
#  'expectation': 2966,
#  'within': 10457,
#  'williams': 10433,
#  'already': 314,
#  'campaign': 1201,
#  'president': 7353,
#  'aspect': 563,
#  'half': 4161,
#  'hour': 4437,
#  'wrong': 10646,
#  'moment': 5965,
#  'less': 5212,
#  'pointless': 7242,
#  'nowhere': 6579,
#  'stand': 8914,
#  'still': 8972,
#  'consistently': 1756,
#  'cheer': 1426,
#  'heard': 4259,
#  'audience': 612,
#  'crowd': 1944,
#  'yell': 10674,
#  'performance': 7055,
#  'par': 6922,
#  'walken': 10132,
#  'deliver': 2118,
#  'strong': 9083,
#  'support': 9180,
#  'underrated': 9902,
#  'lewis': 5236,
#  'black': 942,
#  'vulgar': 10120,
#  'political': 7256,
#  'tone': 9662,
#  'pg13': 7098,
#  'rating': 7592,
#  'overall': 6870,
#  'pay': 6983,
#  'free': 3613,
#  'solid': 8746,
#  'downhill': 2449,
#  'category': 1303,
#  'anything': 475,
#  'central': 1326,
#  'special': 8838,
#  'movie last': 6135,
#  'last night': 5113,
#  'high expectation': 4317,
#  'within minute': 10459,
#  'first minute': 3471,
#  'aspect movie': 565,
#  'movie first': 6099,
#  'first half': 3467,
#  'half hour': 4163,
#  'dont get': 2405,
#  'get wrong': 3811,
#  'wrong movie': 10648,
#  'take turn': 9286,
#  'movie go': 6109,
#  'go nowhere': 3917,
#  'still good': 8981,
#  'funny part': 3679,
#  'one point': 6753,
#  'give great': 3848,
#  'great performance': 4078,
#  'support role': 9185,
#  'think one': 9491,
#  'one character': 6690,
#  'character go': 1376,
#  'funny see': 3681,
#  'pay see': 6986,
#  'see movie': 8325,
#  'half way': 4166,
#  'comedy central': 1635,
#  'dont get wrong': 2406,
#  'give great performance': 3849,
#  'william': 10431,
#  'hurt': 4487,
#  'american': 381,
#  'idol': 4525,
#  'taste': 9307,
#  'bmovie': 985,
#  'project': 7433,
#  'specialist': 8843,
#  'waste': 10204,
#  'track': 9698,
#  'loser': 5455,
#  'former': 3574,
#  'deadly': 2045,
#  'poison': 7243,
#  'current': 1973,
#  'hardy': 4221,
#  'jr': 4917,
#  'possibly': 7298,
#  'handsome': 4183,
#  'dad': 1991,
#  'feature': 3121,
#  'arrogant': 538,
#  'bos': 1026,
#  'horrify': 4418,
#  'sequence': 8411,
#  'chemical': 1431,
#  'production': 7419,
#  'plant': 7161,
#  'wacky': 10122,
#  'government': 4033,
#  'agent': 245,
#  'incident': 4611,
#  'provide': 7463,
#  'inevitable': 4648,
#  'love': 5478,
#  'hero': 4302,
#  'michael': 5857,
#  'pop': 7272,
#  'slimy': 8686,
#  'type': 9862,
#  'wait': 10124,
#  'company': 1672,
#  'product': 7418,
#  'soft': 8740,
#  'drink': 2481,
#  'throughout': 9545,
#  'shot': 8520,
#  'lovingly': 5502,
#  'still pretty': 8987,
#  'pretty good': 7368,
#  'love interest': 5486,
#  'cant wait': 1235,
#  'crap': 1901,
#  'whole': 10400,
#  'case': 1281,
#  'awful': 651,
#  'fool': 3549,
#  'review': 7902,
#  'money': 5969,
#  'spend': 8856,
#  'im': 4546,
#  'fill': 3186,
#  'ten': 9347,
#  'line': 5340,
#  'text': 9377,
#  'piece crap': 7127,
#  'whole movie': 10405,
#  'movie nothing': 6165,
#  'ever happen': 2848,
#  'happen movie': 4189,
#  'didnt get': 2212,
#  'like first': 5288,
#  'waste money': 10209,
#  'bout': 1035,
#  'publish': 7479,
#  'limit': 5334,
#  'summary': 9160,
#  'master': 5754,
#  'drug': 2491,
#  'dealer': 2048,
#  'liveaction': 5381,
#  'cartoon': 1276,
#  'grade': 4036,
#  'praise': 7317,
#  'clown': 1563,
#  'tired': 9625,
#  'stereotype': 8962,
#  'audio': 617,
#  'public': 7476,
#  'access': 73,
#  'luckily': 5521,
#  'buy': 1168,
#  'degenerate': 2105,
#  'avoid': 636,
#  'video': 10061,
#  'disease': 2307,
#  'dont even': 2399,
#  'even know': 2816,
#  'drug dealer': 2494,
#  'act like': 108,
#  'movie bad': 6041,
#  'bad even': 690,
#  'even funny': 2810,
#  'funny character': 3673,
#  'character film': 1371,
#  'film extremely': 3251,
#  'music play': 6330,
#  'play movie': 7175,
#  'movie look': 6144,
#  'buy film': 1170,
#  'film like': 3297,
#  'dont even know': 2400,
#  'movie look like': 6145,
#  'perfect': 7047,
#  'witness': 10471,
#  'netflix': 6430,
#  'computer': 1705,
#  'recommendation': 7729,
#  'engine': 2696,
#  'suggest': 9149,
#  'apparently': 491,
#  'told': 9648,
#  'parallel': 6926,
#  'drawn': 2468,
#  'provoke': 7465,
#  'emotion': 2647,
#  'excitement': 2938,
#  'thomas': 9516,
#  'virtually': 10089,
#  'impossible': 4594,
#  'refuse': 7760,
#  'intelligence': 4710,
#  'bar': 751,
#  'set': 8431,
#  'level': 5235,
#  'upon': 9979,
#  'reflection': 7756,
#  'represent': 7837,
#  'produce': 7415,
#  'response': 7869,
#  'proceed': 7410,
#  'knock': 5023,
#  'execute': 2942,
#  'banal': 745,
#  'hate': 4237,
#  'wes': 10367,
#  'contemporary': 1767,
#  'cinema': 1485,
#  'talent': 9289,
#  'concerned': 1715,
#  'fame': 3052,
#  'ship': 8500,
#  'thisthe': 9514,
#  'thirty': 9513,
#  'mom': 5964,
#  'area': 511,
#  'shoot': 8508,
#  'wouldbe': 10614,
#  'john': 4893,
#  'seedy': 8360,
#  'private': 7397,
#  'drill': 2480,
#  'videotape': 10066,
#  'brutal': 1120,
#  'hapless': 4186,
#  'hand': 4178,
#  'hold': 4359,
#  'camcorder': 1189,
#  'notion': 6571,
#  'mind': 5901,
#  'snuff': 8728,
#  'cultural': 1964,
#  'ticket': 9560,
#  'urban': 9985,
#  'ghetto': 3813,
#  'debt': 2058,
#  'friend': 3627,
#  'atrocious': 592,
#  'approach': 502,
#  'assailant': 567,
#  'james': 4843,
#  'credit': 1920,
#  'knife': 5021,
#  'blackmail': 947,
#  'killer': 4997,
#  'documentary': 2356,
#  'footage': 3553,
#  'problem': 7406,
#  'idea': 4512,
#  'exist': 2949,
#  'amateurish': 370,
#  'alone': 308,
#  'commit': 1661,
#  'assumption': 581,
#  'shock': 8504,
#  'context': 1770,
#  'culture': 1965,
#  'pc': 6989,
#  'relies': 7788,
#  'ironically': 4779,
#  'torture': 9677,
#  'animal': 418,
#  'therefore': 9414,
#  'image': 4564,
#  'violence': 10085,
#  'fake': 3040,
#  'capital': 1241,
#  'pass': 6956,
#  'weve': 10375,
#  'astound': 585,
#  'two': 9836,
#  'inch': 4610,
#  'beard': 791,
#  'skull': 8662,
#  'cap': 1237,
#  'bill': 921,
#  'backwards': 676,
#  'crave': 1905,
#  'potential': 7305,
#  'service': 8429,
#  'primary': 7385,
#  'artist': 549,
#  'please': 7192,
#  'carry': 1272,
#  'expensive': 2968,
#  'stock': 9001,
#  'ahead': 251,
#  'wear': 10295,
#  'creative': 1914,
#  'top': 9669,
#  'respond': 7868,
#  'average': 634,
#  'career': 1258,
#  'history': 4349,
#  'merit': 5842,
#  'yeah': 10657,
#  'youll': 10690,
#  'blame': 955,
#  'dear': 2051,
#  'hook': 4391,
#  'cover': 1890,
#  'buddy': 1127,
#  'blood': 973,
#  'camera': 1192,
#  'watch film': 10223,
#  'much like': 6292,
#  'dont know': 2408,
#  'film make': 3304,
#  'pretty much': 7369,
#  'every film': 2866,
#  'film produce': 3336,
#  'film way': 3396,
#  'im go': 4554,
#  'happen one': 4191,
#  'one interesting': 6721,
#  'also one': 339,
#  'poor guy': 7265,
#  'first time': 3487,
#  'time movie': 9596,
#  'movie director': 6069,
#  'director like': 2268,
#  'make documentary': 5594,
#  'problem movie': 7408,
#  'interest idea': 4725,
#  'doesnt make': 2369,
#  'make film': 5602,
#  'film bad': 3202,
#  'bad guy': 697,
#  'weve get': 10376,
#  'high school': 4321,
#  'go ahead': 3886,
#  'dont expect': 2401,
#  'two hour': 9846,
#  'hour movie': 4442,
#  ...}

# %%
train_transform = fitted_vectorizer.transform(ds['text'])
y = df['label']
print(train_transform)
y
# Out:
#   (0, 10729)	0.03186366145776506
#   (0, 10659)	0.01620587921784738
#   (0, 10548)	0.013165859690184523
#   (0, 10486)	0.023268031264045943
#   (0, 10461)	0.019279358430766065
#   (0, 10438)	0.027112593613534013
#   (0, 10395)	0.025066944258413378
#   (0, 10382)	0.032945055166674724
#   (0, 10378)	0.029222478948662763
#   (0, 10310)	0.012585794368521482
#   (0, 10263)	0.014566634920180467
#   (0, 10247)	0.04298228816021065
#   (0, 10216)	0.012564682217361789
#   (0, 10129)	0.02619760696224098
#   (0, 10072)	0.022952505120751702
#   (0, 9821)	0.04204012511161501
#   (0, 9816)	0.06328236652790126
#   (0, 9807)	0.018630132333408947
#   (0, 9706)	0.03178162047181766
#   (0, 9680)	0.029330658085709137
#   (0, 9564)	0.037181544175310006
#   (0, 9402)	0.02278192767714613
#   (0, 9391)	0.850071209317462
#   (0, 9263)	0.014645120257848681
#   (0, 9107)	0.02377413777453477
#   :	:
#   (4999, 6027)	0.07881562647403094
#   (4999, 5948)	0.10429878315154816
#   (4999, 5857)	0.08004294842718586
#   (4999, 5829)	0.08585461900027652
#   (4999, 5478)	0.04605914697008362
#   (4999, 5269)	0.031611843926477874
#   (4999, 5153)	0.10855393640093716
#   (4999, 4807)	0.5096978364936654
#   (4999, 4666)	0.12338123113490435
#   (4999, 4300)	0.1090948542784018
#   (4999, 4150)	0.1134147197510332
#   (4999, 4138)	0.056845471725791366
#   (4999, 4057)	0.041874228641896535
#   (4999, 3581)	0.1134147197510332
#   (4999, 3575)	0.1070218069896367
#   (4999, 3150)	0.07897048139865478
#   (4999, 3084)	0.10388222680035152
#   (4999, 2939)	0.1134147197510332
#   (4999, 2321)	0.09260236170214921
#   (4999, 1417)	0.08510885928784534
#   (4999, 798)	0.0658471939486568
#   (4999, 697)	0.08570299131001427
#   (4999, 679)	0.08080646961453171
#   (4999, 554)	0.11082181785994098
#   (4999, 191)	0.06977721460658157
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
# 5       1
# 6       0
# 7       1
# 8       0
# 9       0
# 10      0
# 11      1
# 12      0
# 13      0
# 14      0
# 15      0
# 16      0
# 17      0
# 18      1
# 19      1
# 20      1
# 21      0
# 22      1
# 23      1
# 24      0
# 25      1
# 26      1
# 27      0
# 28      0
# 29      0
#        ..
# 4970    0
# 4971    0
# 4972    0
# 4973    1
# 4974    1
# 4975    1
# 4976    1
# 4977    1
# 4978    0
# 4979    0
# 4980    1
# 4981    0
# 4982    1
# 4983    1
# 4984    1
# 4985    0
# 4986    0
# 4987    1
# 4988    0
# 4989    1
# 4990    1
# 4991    1
# 4992    0
# 4993    1
# 4994    1
# 4995    1
# 4996    1
# 4997    0
# 4998    0
# 4999    0
# Name: label, Length: 5000, dtype: int64

# %%
print(type(train_transform),
  train_transform.get_shape(),
  train_transform.ndim,
  train_transform.size)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'> (5000, 10734) 2 403297

# %%
train_array = train_transform.toarray()
print(type(train_array),
  train_array.shape,
  train_array.ndim,
  train_array.size)
# Out:
# <class 'numpy.ndarray'> (5000, 10734) 2 53670000

# %%
print(type(y),
    y.shape,
    y.ndim,
  y.size)
# Out:
# <class 'pandas.core.series.Series'> (5000,) 1 5000

# %%
class Logistic_Regression:
    
    # declaring learning rate & number of iterations (Hyperparameters)
    def __init__(self, learning_rate, no_of_iterations):

        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations

    def sigmoid(self, z):
        return 1/ (1 + np.exp(-z))
         
    # fit function to train the model with dataset
    def fit(self, X, Y):

        # number of data points in the dataset (number of rows)  -->  m
        # number of input features in the dataset (number of columns)  --> n
        self.m, self.n = X.shape

        #initiating weight & bias value

        self.weights = np.zeros(self.n)
        self.bias = 0
        
        self.X = X
        self.Y = Y     
        
        # implementing Gradient Descent for Optimization

        for i in range(self.no_of_iterations):
            self.update_model_parameters()
            

    def update_model_parameters(self):

        # Y_hat formula (sigmoid function)

        Y_hat = self.sigmoid( self.X.dot(self.weights) + self.bias )  



        # derivaties

        dw = (1/self.m)*np.dot(self.X.T, (Y_hat - self.Y))
        db = (1/self.m)*np.sum(Y_hat - self.Y)

        # updating the weights & bias using gradient descent

        self.weights = self.weights - dw * self.learning_rate
        self.bias = self.bias - self.learning_rate * db
                
            
    # Sigmoid Equation & Decision Boundary

    def predict(self, X):

        Y_pred = 1 / (1 + np.exp( - (X.dot(self.weights) + self.bias ) ))     
        Y_pred = np.where( Y_pred > 0.5, 1, 0)
        return Y_pred

# %%
X_test = train_array
y_test = y

# %%
X_train, X_test, y_train, y_test = train_test_split(train_array, y,
                                                    test_size=0.3)

# %%
model = Logistic_Regression(learning_rate=0.9, no_of_iterations=10000)

# %%
model.fit(X_train, y_train)

# %%
predictions = model.predict(X_test)

# %%
print(accuracy_score(y_test, predictions))
# Out:
# 0.852

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[190,  54],
#        [ 51, 205]], dtype=int64)

# %%
df['label'].value_counts()
# Out:
# 1    2505
# 0    2495
# Name: label, dtype: int64

# %%
y_test.shape
# Out:
# (500,)

# %% [markdown]
# # testing manually

# %%
text=["The movie is good. It has interesting plot. Although some of the scenes were gruesome, nevertheless overall the movie is quite satisfying to watch. I would recommend to watch this movie if you're looking for some new plot to see."]

# %%
train_transform1 = fitted_vectorizer.transform(text)

# %%
text_array = train_transform1.toarray()

# %%
predictions = model.predict(text_array)
predictions
# Out:
# array([0])

# %%
if predictions[0] == 0:
    print("Negative")
else:
    print("Positive")
# Out:
# Negative

# %%
model1 = Logistic_Regression(learning_rate=0.5, no_of_iterations=10000)

# %%
model1.fit(X_train, y_train)

# %%
text1=["Hi, Everyone, Oh, Boy... This one is a lulu. It has really bad background music whenever they can squeeze it in. There are three bad guys who, I guess, are the stars of this. They beat people up and chop people up and crash trucks and bulldozers into people. Usual stuff.<br /><br />The woman who is sending them on their missions is unable to move her mouth when she speaks. It's sort of like watching a bad ventriloquist who is her own dummy. She walks like she is balancing an egg on her head.<br /><br />The wardrobe is 70s leisure style for the men and blah for the female lead who is supposed to be a good nurse. The bad novocain mouth woman wears red. A silk frock perhaps, or maybe just a poplin windbreaker that is too big.<br /><br />I actually liked the ending even though it did not make a lot of sense. It lets us in on what happened earlier in the film.<br /><br />The police officers are OK. Some bad, some good, all stupid except two. The two bright ones could have worked again in Hollywood.<br /><br />The movie starts interestingly enough and ends with a surprise. The middle sucks. The guy in the diner who gives a free hamburger to the star does a good job. He is like a 1940s character actor. Great voice.<br /><br />This one is a bit too long. The lady with marbles in her mouth could have had just a couple of lines and the rest could have been said by a parrot. It would have been easier to understand a bird.<br /><br />Her scene with a sword could have been handled by a trained woodpecker.<br /><br />Tom Willett"]

# %%
predictions1 = model1.predict(text_array)
predictions1
# Out:
# array([1])

# %%
if predictions1[0] == 0:
    print("Negative")
else:
    print("Positive")
# Out:
# Positive

# %%
train_transform2 = fitted_vectorizer.transform(text1)
text_array2 = train_transform2.toarray()
text_array2
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
predictions2 = model1.predict(text_array2)
predictions2
# Out:
# array([0])

# %%
if predictions2[0] == 0:
    print("Negative")
else:
    print("Positive")
# Out:
# Negative
